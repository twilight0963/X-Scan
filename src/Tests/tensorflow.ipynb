# %%
import tensorflow

print(tensorflow.__version__)
# Out:
# 2025-10-21 10:08:39.429261: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-21 10:08:39.465058: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-21 10:08:39.466592: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-21 10:08:40.338877: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2.13.1

# %%
from PIL import Image
import os

def verify_images(folder):
    for root, _, files in os.walk(folder):
        for file in files:
            path = os.path.join(root, file)
            try:
                img = Image.open(path)
                img.verify()  # just check validity
            except Exception as e:
                print(f"Bad file removed: {path}")
                os.remove(path)

verify_images("./Datasets/MergedData/train")
verify_images("./Datasets/MergedData/test")

# %%
import torch
torch.cuda.is_available()
# Out:
# True
